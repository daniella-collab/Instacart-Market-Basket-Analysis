# %% [markdown]
# ##### Contents:
# ###### 1. Import Libraries
# ###### 2. Import dataframes
# ###### 3. Use groupby and agg functions to calculate mean of user_order_number
# ###### 4. Create Loyalty Flag for Exisiting Customer
# ###### 5. Assign loyalty flag
# ###### 6. Targeting Diverse Spenders
# ###### 7. Order Frequency Flag Based on Median Ordering Behavior
# ###### 8. Export dataframe

# %% [markdown]
# ##### 1. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ##### 2. Import dataframes

# %%
#Import orders_products_merged
path = r'C:\Users\Daniella\ACH4 - Instacart Basket Analysis'

# %%
ords_prods_merge=pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'ords_prods_merge_updated(new).pkl'))

# %%
# Create a subset of 1 million rows
df = ords_prods_merge[:1000000]

# %%
# Check shape of new subset
df.shape
# Out:
# (1000000, 18)

# %% [markdown]
# ##### 3. Use groupby and agg functions to calculate mean of user_order_number

# %%
df.groupby(['department_id']).agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %% [markdown]
# The mean order numbers seem to be higher for each department when looking at the entire data frame.

# %% [markdown]
# ##### 4.Create Loyalty Flag for Exisiting Customer

# %%
# Create new column "max_order"
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Daniella\AppData\Local\Temp\ipykernel_34024\2088177565.py:2: FutureWarning: The provided callable <function max at 0x0000020A4C8EE7A0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check new column
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2539329        1             1                       2
# 1    2539329        1             1                       2
# 2    2539329        1             1                       2
# 3    2539329        1             1                       2
# 4    2539329        1             1                       2
# 5    2398795        1             2                       3
# 6    2398795        1             2                       3
# 7    2398795        1             2                       3
# 8    2398795        1             2                       3
# 9    2398795        1             2                       3
# 10   2398795        1             2                       3
# 11    473747        1             3                       3
# 12    473747        1             3                       3
# 13    473747        1             3                       3
# 14    473747        1             3                       3
# 15    473747        1             3                       3
# 16   2254736        1             4                       4
# 17   2254736        1             4                       4
# 18   2254736        1             4                       4
# 19   2254736        1             4                       4
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   8                     NaN       14084                  2
# 2                   8                     NaN       12427                  3
# 3                   8                     NaN       26088                  4
# 4                   8                     NaN       26405                  5
# 5                   7                    15.0         196                  1
# 6                   7                    15.0       10258                  2
# 7                   7                    15.0       12427                  3
# 8                   7                    15.0       13176                  4
# 9                   7                    15.0       26088                  5
# 10                  7                    15.0       13032                  6
# 11                 12                    21.0         196                  1
# 12                 12                    21.0       12427                  2
# 13                 12                    21.0       10258                  3
# 14                 12                    21.0       25133                  4
# 15                 12                    21.0       30450                  5
# 16                  7                    29.0         196                  1
# 17                  7                    29.0       12427                  2
# 18                  7                    29.0       10258                  3
# 19                  7                    29.0       25133                  4
#
#     reordered                             product_name  aisle_id  \
# 0           0                                     Soda        77
# 1           0  Organic Unsweetened Vanilla Almond Milk        91
# 2           0                      Original Beef Jerky        23
# 3           0               Aged White Cheddar Popcorn        23
# 4           0         XL Pick-A-Size Paper Towel Rolls        54
# 5           1                                     Soda        77
# 6           0                               Pistachios       117
# 7           1                      Original Beef Jerky        23
# 8           0                   Bag of Organic Bananas        24
# 9           1               Aged White Cheddar Popcorn        23
# 10          0                    Cinnamon Toast Crunch       121
# 11          1                                     Soda        77
# 12          1                      Original Beef Jerky        23
# 13          1                               Pistachios       117
# 14          0                    Organic String Cheese        21
# 15          0                     Creamy Almond Butter        88
# 16          1                                     Soda        77
# 17          1                      Original Beef Jerky        23
# 18          1                               Pistachios       117
# 19          1                    Organic String Cheese        21
#
#     department_id  prices _merge    price_range_loc     busiest_day  \
# 0               7     9.0   both  Mid-range product  Regularly busy
# 1              16    12.5   both  Mid-range product  Regularly busy
# 2              19     4.4   both  Low-range product  Regularly busy
# 3              19     4.7   both  Low-range product  Regularly busy
# 4              17     1.0   both  Low-range product  Regularly busy
# 5               7     9.0   both  Mid-range product  Regularly busy
# 6              19     3.0   both  Low-range product  Regularly busy
# 7              19     4.4   both  Low-range product  Regularly busy
# 8               4    10.3   both  Mid-range product  Regularly busy
# 9              19     4.7   both  Low-range product  Regularly busy
# 10             14     4.0   both  Low-range product  Regularly busy
# 11              7     9.0   both  Mid-range product  Regularly busy
# 12             19     4.4   both  Low-range product  Regularly busy
# 13             19     3.0   both  Low-range product  Regularly busy
# 14             16     8.6   both  Mid-range product  Regularly busy
# 15             13     3.2   both  Low-range product  Regularly busy
# 16              7     9.0   both  Mid-range product      Least busy
# 17             19     4.4   both  Low-range product      Least busy
# 18             19     3.0   both  Low-range product      Least busy
# 19             16     8.6   both  Mid-range product      Least busy
#
#       busiest_days busiest_period_of_day  max_order
# 0   Regularly busy        Average orders         10
# 1   Regularly busy        Average orders         10
# 2   Regularly busy        Average orders         10
# 3   Regularly busy        Average orders         10
# 4   Regularly busy        Average orders         10
# 5     Slowest days        Average orders         10
# 6     Slowest days        Average orders         10
# 7     Slowest days        Average orders         10
# 8     Slowest days        Average orders         10
# 9     Slowest days        Average orders         10
# 10    Slowest days        Average orders         10
# 11    Slowest days           Most orders         10
# 12    Slowest days           Most orders         10
# 13    Slowest days           Most orders         10
# 14    Slowest days           Most orders         10
# 15    Slowest days           Most orders         10
# 16    Slowest days        Average orders         10
# 17    Slowest days        Average orders         10
# 18    Slowest days        Average orders         10
# 19    Slowest days        Average orders         10

# %% [markdown]
# ##### 5. Assign loyalty flag

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check loyalty flags
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Check loyalty flag in dataframe
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number','max_order']].head(20)
# Out:
#     user_id  loyalty_flag  order_number  max_order
# 0         1  New customer             1         10
# 1         1  New customer             1         10
# 2         1  New customer             1         10
# 3         1  New customer             1         10
# 4         1  New customer             1         10
# 5         1  New customer             2         10
# 6         1  New customer             2         10
# 7         1  New customer             2         10
# 8         1  New customer             2         10
# 9         1  New customer             2         10
# 10        1  New customer             2         10
# 11        1  New customer             3         10
# 12        1  New customer             3         10
# 13        1  New customer             3         10
# 14        1  New customer             3         10
# 15        1  New customer             3         10
# 16        1  New customer             4         10
# 17        1  New customer             4         10
# 18        1  New customer             4         10
# 19        1  New customer             4         10

# %%
# Find the min, max and mean of each loyalty flag
ords_prods_merge.groupby(['loyalty_flag']).agg({'prices':['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386335  1.0  99999.0
# New customer      13.294669  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ##### 6. The team now wants to target different types of spenders in their marketing campaigns.
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”\n",
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.

# %%
# Create new column for average spender
ords_prods_merge['average_spend']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\Daniella\AppData\Local\Temp\ipykernel_34024\2864952345.py:2: FutureWarning: The provided callable <function mean at 0x0000020A4C8EF1A0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_spend']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Create flag for low spender
ords_prods_merge.loc[ords_prods_merge['average_spend']<10,'spender_flag']='Low_spender'

# %%
# Create flag for high spender
ords_prods_merge.loc[ords_prods_merge['average_spend']>= 10, 'spender_flag'] = 'High_spender'

# %%
# Check spender flags
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low_spender     31770614
# High_spender      634245
# Name: count, dtype: int64

# %%
# View columns of updated data frame
ords_prods_merge[['user_id', 'average_spend', 'spender_flag', 'prices']].head(20)
# Out:
#     user_id  average_spend spender_flag  prices
# 0         1       6.367797  Low_spender     9.0
# 1         1       6.367797  Low_spender    12.5
# 2         1       6.367797  Low_spender     4.4
# 3         1       6.367797  Low_spender     4.7
# 4         1       6.367797  Low_spender     1.0
# 5         1       6.367797  Low_spender     9.0
# 6         1       6.367797  Low_spender     3.0
# 7         1       6.367797  Low_spender     4.4
# 8         1       6.367797  Low_spender    10.3
# 9         1       6.367797  Low_spender     4.7
# 10        1       6.367797  Low_spender     4.0
# 11        1       6.367797  Low_spender     9.0
# 12        1       6.367797  Low_spender     4.4
# 13        1       6.367797  Low_spender     3.0
# 14        1       6.367797  Low_spender     8.6
# 15        1       6.367797  Low_spender     3.2
# 16        1       6.367797  Low_spender     9.0
# 17        1       6.367797  Low_spender     4.4
# 18        1       6.367797  Low_spender     3.0
# 19        1       6.367797  Low_spender     8.6

# %% [markdown]
# ##### 7. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
#
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Create a new column for frequet users
ords_prods_merge['Customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\Daniella\AppData\Local\Temp\ipykernel_34024\1862414263.py:2: FutureWarning: The provided callable <function median at 0x0000020A4CA61800> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['Customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Create flag on order frequency
ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] > 20, 'frequency_flag'] = 'Not regular customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['Customer_frequency']>10) & (ords_prods_merge['Customer_frequency']<=20),'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check flag frequency
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer       21559853
# Regular customer         7208564
# Not regular customer     3636437
# NaN                            5
# Name: count, dtype: int64

# %% [markdown]
# ##### NaN value means that there are only 5 customers who have only bought once

# %%
# View columns of  data frame
ords_prods_merge[['user_id','days_since_prior_order', 'Customer_frequency', 'frequency_flag']].head(20)
# Out:
#     user_id  days_since_prior_order  Customer_frequency        frequency_flag
# 0         1                     NaN                20.5  Not regular customer
# 1         1                     NaN                20.5  Not regular customer
# 2         1                     NaN                20.5  Not regular customer
# 3         1                     NaN                20.5  Not regular customer
# 4         1                     NaN                20.5  Not regular customer
# 5         1                    15.0                20.5  Not regular customer
# 6         1                    15.0                20.5  Not regular customer
# 7         1                    15.0                20.5  Not regular customer
# 8         1                    15.0                20.5  Not regular customer
# 9         1                    15.0                20.5  Not regular customer
# 10        1                    15.0                20.5  Not regular customer
# 11        1                    21.0                20.5  Not regular customer
# 12        1                    21.0                20.5  Not regular customer
# 13        1                    21.0                20.5  Not regular customer
# 14        1                    21.0                20.5  Not regular customer
# 15        1                    21.0                20.5  Not regular customer
# 16        1                    29.0                20.5  Not regular customer
# 17        1                    29.0                20.5  Not regular customer
# 18        1                    29.0                20.5  Not regular customer
# 19        1                    29.0                20.5  Not regular customer

# %%
ords_prods_merge['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956429e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 1576        912404       17            12                       2
# 1638        603376       17            22                       6
# 16522      3264360      135             2                       2
# 16528       892534      135             3                       0
# 53672       229704      342             8                       1
# ...            ...      ...           ...                     ...
# 32320511   3172853   205650            18                       1
# 32347717   2504315   205818             3                       5
# 32347727   1108388   205818             5                       4
# 32380527   1916142   206049             1                       2
# 32380551    379732   206049             4                       1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 1576                     14                     5.0       21553
# 1638                     16                     4.0       21553
# 16522                    21                    13.0       21553
# 16528                     8                    12.0       21553
# 53672                    19                    30.0       21553
# ...                     ...                     ...         ...
# 32320511                  9                     7.0       21553
# 32347717                 15                     3.0       21553
# 32347727                  5                     1.0       21553
# 32380527                 17                     NaN       21553
# 32380551                 14                     5.0       21553
#
#           add_to_cart_order  reordered                      product_name  ...  \
# 1576                      5          0  Lowfat 2% Milkfat Cottage Cheese  ...
# 1638                      3          1  Lowfat 2% Milkfat Cottage Cheese  ...
# 16522                     6          0  Lowfat 2% Milkfat Cottage Cheese  ...
# 16528                     3          1  Lowfat 2% Milkfat Cottage Cheese  ...
# 53672                     9          0  Lowfat 2% Milkfat Cottage Cheese  ...
# ...                     ...        ...                               ...  ...
# 32320511                 17          1  Lowfat 2% Milkfat Cottage Cheese  ...
# 32347717                 13          0  Lowfat 2% Milkfat Cottage Cheese  ...
# 32347727                  5          1  Lowfat 2% Milkfat Cottage Cheese  ...
# 32380527                  2          0  Lowfat 2% Milkfat Cottage Cheese  ...
# 32380551                  4          1  Lowfat 2% Milkfat Cottage Cheese  ...
#
#              price_range_loc     busiest_day    busiest_days  \
# 1576      High-range product  Regularly busy  Regularly busy
# 1638      High-range product  Regularly busy  Regularly busy
# 16522     High-range product  Regularly busy  Regularly busy
# 16528     High-range product     Busiest day    Busiest days
# 53672     High-range product  Regularly busy    Busiest days
# ...                      ...             ...             ...
# 32320511  High-range product  Regularly busy    Busiest days
# 32347717  High-range product  Regularly busy  Regularly busy
# 32347727  High-range product      Least busy    Slowest days
# 32380527  High-range product  Regularly busy  Regularly busy
# 32380551  High-range product  Regularly busy    Busiest days
#
#          busiest_period_of_day max_order      loyalty_flag average_spend  \
# 1576               Most orders        40  Regular customer    108.648300
# 1638               Most orders        40  Regular customer    108.648300
# 16522           Average orders         4      New customer   1154.792236
# 16528           Average orders         4      New customer   1154.792236
# 53672           Average orders        16  Regular customer    114.426620
# ...                        ...       ...               ...           ...
# 32320511           Most orders        25  Regular customer    351.141632
# 32347717           Most orders        25  Regular customer    170.073776
# 32347727         Fewest orders        25  Regular customer    170.073776
# 32380527        Average orders         5      New customer    938.031250
# 32380551           Most orders         5      New customer    938.031250
#
#           spender_flag  Customer_frequency        frequency_flag
# 1576      High_spender                 5.0     Frequent customer
# 1638      High_spender                 5.0     Frequent customer
# 16522     High_spender                12.0      Regular customer
# 16528     High_spender                12.0      Regular customer
# 53672     High_spender                23.0  Not regular customer
# ...                ...                 ...                   ...
# 32320511  High_spender                 6.0     Frequent customer
# 32347717  High_spender                13.0      Regular customer
# 32347727  High_spender                13.0      Regular customer
# 32380527  High_spender                 7.0     Frequent customer
# 32380551  High_spender                 7.0     Frequent customer
#
# [5127 rows x 24 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ##### 8. Export dataframe

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'ords_prods_grouped.pkl'))
